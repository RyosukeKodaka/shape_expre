# %%
import pandas as pd
import numpy as np
import xgboost
import shap
import warnings
import transformers

# 警告を非表示にする
warnings.filterwarnings('ignore')# このデータセットは倫理的によろしくないらしく警告文がでる

# %% [markdown]
# # SHAPとは

# %% [markdown]
# - 「それぞれの特徴変数がその予想にどのような影響を与えたか」を算出するものです。これにより、ある特徴変数の値の増減が与える影響を可視化することができます。以下にデフォルトで用意されているボストンの価格予測データセットを用いて、Pythonでの構築コードと可視化したグラフを紹介する
# - XGBoost、LightGBM、CatBoost、scikit-learn、pysparkの木モデルに対してサポートされている

# %% [markdown]
# <center><img src="./img/shap1.jpg" width=600px><br>
# </center>

# %% [markdown]
# # 1. アンサンブル学習(XGBoost/LightGBM/CatBoost/scikit-learn/pyspark models)

# %% [markdown]
# ## bostonの家賃に関するデータセットを用いる

# %% [markdown]
# 特徴変数 説明
# - CRIM   :人口 1 人当たりの犯罪発生数
# - ZN     :25,000 平方フィート以上の住居区画の占める割合
# - INDUS  :小売業以外の商業が占める面積の割合
# - CHAS   :チャールズ川によるダミー変数 (1: 川の周辺, 0: それ以外)
# - NOX    :NOxの濃度
# - RM     :住居の平均部屋数
# - AGE    :1940年より前に建てられた物件の割合
# - DIS    :5つのボストン市の雇用施設からの距離 (重み付け済)
# - RAD    :環状高速道路へのアクセスしやすさ
# - TAX    :$10,000ドルあたりの不動産税率の総計
# - PTRATIO:町毎の児童と教師の比率
# - B      :町毎の黒人 (Bk) の比率を次の式で表したもの。1000(Bk – 0.63)^2
# - LSTAT  :給与の低い職業に従事する人口の割合 (%)

# %%
X, y = shap.datasets.boston()

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
y[:5]
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2])

# %% [markdown]
# ## shapを使って特徴量ごとの影響度を確認してみる

# %%
model = xgboost.XGBRegressor().fit(X, y)

# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X) # 各特徴量のshap値

# %% [markdown]
# ## 1. plots.waterfallU()
# - 各データにおいて、期待値を基準として、各特徴量がどれくらいの影響を及ぼしたか確認できる
# - 目的変数が大きくなるような特徴量が赤、目的変数が小さくなるような特徴量が青
# - 上に行くほど数字が大きく、影響度が大きい

# %%
# 最初のデータに対する目的変数に対する特徴量の影響度を見てみる
shap.plots.waterfall(shap_values[0]) # 0~505

# %% [markdown]
# ## 2. plots.force()
# - shap.plots.waterfallのデータを横並びにしたイメージ
# - higher vs lower みたいなバトル的な構図

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
shap.plots.force(shap_values[0],matplotlib=True)
# matplotlib=Trueがないと謎のエラーが発生

# %%
shap.plots.force(shap_values)
# javascriptに対応していないからエラーになる??
# Out:
# <div id='iJ8EM307I4SBVBN4KWS36'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %% [markdown]
# <center><img src="./img/shap2.png" width=600px><br>
# ほんとはこんな感じ</center>

# %% [markdown]
# ## 3. plots.scatter()
# - ある特徴量がモデルの出力にどのような影響を与えるかを理解するために
# すべてのデータに対して、その特徴量の値とshap値でプロットすることができる
# - color引数に他の特徴量を渡すと相互作用効果を記してくれる
# -　以下の例では、特徴量にRM（地域の家ごとの平均部屋数）を選択し、
# 相互作用を見る特徴量として、AD（放射状高速道路へのアクセスの指標）を選択している
# (説明テンソル全体をcolor引数に渡すと、散布図は色付けするのに最適な特徴を選んでくれる)

# %%
shap.plots.scatter(shap_values[:,"RM"],color=shap_values)

# %% [markdown]
# ## 4. plots.beeswarm()
# - どの特徴量がモデルにとって最も重要であるかを確認するために、すべてのサンプルについて、
# すべての特徴量のSHAP値をプロットすることができる。以下のプロットは、全サンプルのSHAP値の大きさの合計で特徴量をソートし、
# SHAP値を使って各特徴量がモデル出力に与える影響の分布を表している。
# 色は特徴量の値（赤が高く、青が低い）を表しています。
# これにより、例えば、LSTAT（人口に占める地位の低い人の割合）が高いと、予測される住宅価格が低くなることがわかる。

# %%
shap.plots.beeswarm(shap_values)

# %% [markdown]
# ## 5. plots.bar()
# - 各特徴量の絶対平均値を取り、棒グラフを作成

# %%
shap.plots.bar(shap_values)

# %% [markdown]
# # 自然言語

# %%
# load a transformers pipeline model
model = transformers.pipeline('sentiment-analysis', return_all_scores=True)

# explain the model on two sample inputs
explainer = shap.Explainer(model) 
shap_values = explainer(["What a great movie! ...if you have no taste."])

# visualize the first prediction's explanation for the POSITIVE output class
shap.plots.text(shap_values[0, :, "POSITIVE"])
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
#   0%|          | 0/240 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ### 参照URL：https://github.com/slundberg/shap#citations
